# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
import peakutils

# %%
img=mpimg.imread('/home/diego/jetsi.png')

# %%
img
# Out:
# array([[0.25882354, 0.2627451 , 0.2627451 , ..., 0.2627451 , 0.2627451 ,
#         0.2627451 ],
#        [0.26666668, 0.26666668, 0.26666668, ..., 0.27058825, 0.27058825,
#         0.27058825],
#        [0.27058825, 0.27058825, 0.27058825, ..., 0.2784314 , 0.28627452,
#         0.28627452],
#        ...,
#        [0.27450982, 0.26666668, 0.2627451 , ..., 0.3647059 , 0.38039216,
#         0.38039216],
#        [0.27058825, 0.27058825, 0.27450982, ..., 0.3764706 , 0.3764706 ,
#         0.3764706 ],
#        [0.26666668, 0.27450982, 0.28235295, ..., 0.38431373, 0.3764706 ,
#         0.3764706 ]], dtype=float32)

# %%
img.shape
# Out:
# (830, 1114)

# %%
luminosidad_x=np.zeros(1114)

# %%
for ii in range(1114):
        luminosidad_x[ii]=img[:,ii].sum()

# %%
plt.plot(luminosidad_x)

# %%
imgplot = plt.imshow(img)
plt.plot(luminosidad_x,'r')

# %%
indexes = peakutils.indexes(luminosidad_x, thres=0.01/max(luminosidad_x), min_dist=20)

# %%
indexes
# Out:
# array([  14,   56,   83,  104,  127,  151,  196,  259,  294,  344,  394,
#         445,  471,  510,  537,  567,  594,  625,  651,  690,  740,  792,
#         815,  849,  896,  924,  947,  972,  996, 1019, 1042, 1067, 1104])

# %%
imgplot = plt.imshow(img)
plt.plot(luminosidad_x,'r')
for pixel_x in indexes:
    plt.plot([pixel_x,pixel_x],[0,830],'r')
